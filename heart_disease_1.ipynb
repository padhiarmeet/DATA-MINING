# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#age - age in years

#sex - (1 = male; 0 = female)

#cp - chest pain type

#trestbps - resting blood pressure (in mm Hg on admission to the hospital)

#chol - serum cholestoral in mg/dl no ideal if HDL or LDL

#fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)

#restecg - resting electrocardiographic results

#thalach - maximum heart rate achieved

#exang - exercise induced angina (1 = yes; 0 = no)

#oldpeak - ST depression induced by exercise relative to rest

#slope - the slope of the peak exercise ST segment

#ca - number of major vessels (0-3) colored by flourosopy

#thal - 3 = normal; 6 = fixed defect; 7 = reversable defect

#target - have disease or not (1=yes, 0=no)

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("heart.csv")
#       2 df.head()
#
# File e:\DATA MINING\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (302, 14)

# %%
df[(df['age'] < 0) | (df['age'] > 100)].sum()
# Out:
# age         0.0
# sex         0.0
# cp          0.0
# trestbps    0.0
# chol        0.0
# fbs         0.0
# restecg     0.0
# thalach     0.0
# exang       0.0
# oldpeak     0.0
# slope       0.0
# ca          0.0
# thal        0.0
# target      0.0
# dtype: float64

# %%
df['age'].value_counts()
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 60    11
# 62    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 53     8
# 61     8
# 55     8
# 65     8
# 45     8
# 42     8
# 43     8
# 48     7
# 46     7
# 66     7
# 50     7
# 47     5
# 49     5
# 70     4
# 35     4
# 39     4
# 68     4
# 69     3
# 71     3
# 40     3
# 34     2
# 38     2
# 37     2
# 29     1
# 76     1
# 77     1
# 74     1
# Name: count, dtype: int64

# %%
df['sex'] = df['sex'].map({1:"male", 0:"female"})

# %%
df.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    male   0       125   212    0        1      168      0      1.0
# 1   53    male   0       140   203    1        0      155      1      3.1
# 2   70    male   0       145   174    0        1      125      1      2.6
# 3   61    male   0       148   203    0        1      161      0      0.0
# 4   62  female   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
df['thal'].value_counts()
# Out:
# thal
# 2    165
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64

# %%
df = df[df['thal'] > 0]
#thal is thalassemia and  value is 3 6 7 but here we have to remove only 0 due to not enough rows

# %%
df.shape
# Out:
# (300, 14)

# %%
df['ca'].value_counts()
#ca is number of major vessels affected range is 0 to 3
#0 means no major
#3 means majority
# Out:
# ca
# 0    173
# 1     65
# 2     38
# 3     20
# 4      4
# Name: count, dtype: int64

# %%
#okay so remove 4
df = df[df['ca'] < 4]

# %%
df.shape
# Out:
# (296, 14)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    141
# 2     83
# 1     49
# 3     23
# Name: count, dtype: int64

# %%
df['cp'] = df['cp'].map({0:'typical angina',1:'atypical angina',
                            2:'non anginal pain',3:'asymptomatic'})

# %%
df.head()
# Out:
#    age     sex              cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   52    male  typical angina       125   212    0        1      168      0
# 1   53    male  typical angina       140   203    1        0      155      1
# 2   70    male  typical angina       145   174    0        1      125      1
# 3   61    male  typical angina       148   203    0        1      161      0
# 4   62  female  typical angina       138   294    1        1      106      0
#
#    oldpeak  slope  ca  thal  target
# 0      1.0      2   2     3       0
# 1      3.1      0   0     3       0
# 2      2.6      0   0     3       0
# 3      0.0      2   1     3       0
# 4      1.9      1   3     2       0

# %%
df['slope'].value_counts()
# Out:
# slope
# 2    138
# 1    137
# 0     21
# Name: count, dtype: int64

# %%
df['slope'] = df['slope'].map({2 : "downsloping", 0 : "upsloping", 1 : "flat"})

# %%
df.head()
# Out:
#    age     sex              cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   52    male  typical angina       125   212    0        1      168      0
# 1   53    male  typical angina       140   203    1        0      155      1
# 2   70    male  typical angina       145   174    0        1      125      1
# 3   61    male  typical angina       148   203    0        1      161      0
# 4   62  female  typical angina       138   294    1        1      106      0
#
#    oldpeak        slope  ca  thal  target
# 0      1.0  downsloping   2     3       0
# 1      3.1    upsloping   0     3       0
# 2      2.6    upsloping   0     3       0
# 3      0.0  downsloping   1     3       0
# 4      1.9         flat   3     2       0

# %%
df['thal'].value_counts()
# Out:
# thal
# 2    163
# 3    115
# 1     18
# Name: count, dtype: int64

# %%
df['thal'] = df['thal'].map({2:"fixed defect", 3 : "reversible defect", 1 : "normal"})

# %%
df.head()
# Out:
#    age     sex              cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   52    male  typical angina       125   212    0        1      168      0
# 1   53    male  typical angina       140   203    1        0      155      1
# 2   70    male  typical angina       145   174    0        1      125      1
# 3   61    male  typical angina       148   203    0        1      161      0
# 4   62  female  typical angina       138   294    1        1      106      0
#
#    oldpeak        slope  ca               thal  target
# 0      1.0  downsloping   2  reversible defect       0
# 1      3.1    upsloping   0  reversible defect       0
# 2      2.6    upsloping   0  reversible defect       0
# 3      0.0  downsloping   1  reversible defect       0
# 4      1.9         flat   3       fixed defect       0

# %%
#trestbps means resting blood pressure measured when a patient is admitted to the hospital
#and range 94 to 200
df[(df['trestbps'] < 94) | df['trestbps'] > 200].sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang         0
# oldpeak     0.0
# slope         0
# ca            0
# thal          0
# target        0
# dtype: object

# %%
df.describe([0,0.05,0.50,0.90,0.99,1])
# Out:
#               age   trestbps        chol        fbs     restecg     thalach  \
# count  296.000000  296.00000  296.000000  296.00000  296.000000  296.000000
# mean    54.523649  131.60473  247.155405    0.14527    0.523649  149.560811
# std      9.059471   17.72662   51.977011    0.35297    0.526692   22.970792
# min     29.000000   94.00000  126.000000    0.00000    0.000000   71.000000
# 0%      29.000000   94.00000  126.000000    0.00000    0.000000   71.000000
# 5%      40.000000  108.00000  175.750000    0.00000    0.000000  108.000000
# 50%     56.000000  130.00000  242.500000    0.00000    1.000000  152.500000
# 90%     66.000000  152.00000  309.000000    1.00000    1.000000  177.500000
# 99%     71.150000  180.00000  407.100000    1.00000    2.000000  192.100000
# 100%    77.000000  200.00000  564.000000    1.00000    2.000000  202.000000
# max     77.000000  200.00000  564.000000    1.00000    2.000000  202.000000
#
#             exang     oldpeak          ca      target
# ...

# %%
df.boxplot(['age','trestbps','oldpeak','thalach','chol'],)
plt.yticks([80, 100,170,200,300,400,380,500,600])
# Out:
# ([<matplotlib.axis.YTick at 0x1afe9a91130>,
# ...
#  [Text(0, 80, '80'),
#   Text(0, 100, '100'),
#   Text(0, 170, '170'),
#   Text(0, 200, '200'),
#   Text(0, 300, '300'),
#   Text(0, 400, '400'),
#   Text(0, 380, '380'),
#   Text(0, 500, '500'),
#   Text(0, 600, '600')])

# %%
df = df[df['trestbps'] < 170]

# %%
df = df[df['thalach'] > 80]

# %%
df = df[df['chol'] < 380]

# %%
df.boxplot(['age','trestbps','oldpeak','thalach','chol'],)
# Out:
# <Axes: >
