# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>K Means</b></center>
# <center><b><h1>Meet pahiyar | 23010101180 </b></center>
# <pre>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the BankChurners dataset
df = pd.read_csv("BankChurners.csv")
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %%
# Use only Total_Trans_Amt column
X = df[['Total_Trans_Amt']].values
print(X[:10])
# Out:
# [[1144]
#  [1291]
#  [1887]
#  [1171]
#  [ 816]
#  [1088]
#  [1330]
#  [1538]
#  [1350]
#  [1441]]

# %%
def euclidean_distance(a, b):
    return np.sqrt(np.sum((np.array(a) - np.array(b))**2))

# %%
def update_cluster_center(cluster_data):
    sum = [0,0]
    for i in cluster_data:
        sum[0] = sum[0] + i[0]
        sum[1] = sum[1] + i[1]
    return [sum[0]/len(cluster_data), sum[1]/len(cluster_data)]

# %%
def kmeans(X, k, max_iters=100):
    # Randomly choose centroids
    np.random.seed(42)
    centroids = X[np.random.choice(range(len(X)), k, replace=False)]
    
    for _ in range(max_iters):
        clusters = [[] for _ in range(k)]
        
        # Assign points to nearest centroid
        for point in X:
            distances = [euclidean_distance(point, c) for c in centroids]
            cluster_idx = np.argmin(distances)
            clusters[cluster_idx].append(point)
        
        new_centroids = []
        for cluster in clusters:
            if cluster: 
                new_centroids.append(np.mean(cluster, axis=0))
            else:
                new_centroids.append(centroids[len(new_centroids)])
        
        new_centroids = np.array(new_centroids)
        
        # Convergence check
        if np.allclose(centroids, new_centroids):
            break
        centroids = new_centroids
    
    return centroids, clusters

# %%
kmeans(X, k=3)  # Example with 3 clusters
# Out:
# (array([[ 2045.90174873],
#         [ 4895.74611399],
#         [14602.672346  ]]),
#  [[array([1144]),
#    array([1291]),
#    array([1887]),
#    array([1171]),
#    array([816]),
#    array([1088]),
#    array([1330]),
#    array([1538]),
#    array([1350]),
#    array([1441]),
#    array([1201]),
#    array([1314]),
#    array([1539]),
#    array([1311]),
#    array([1570]),
#    array([1348]),
#    array([1671]),
#    array([1028]),
#    array([1336]),
#    array([1207]),
#    array([1178]),
#    array([692]),
#    array([931]),
#    array([1126]),
#    array([1110]),
#    array([1051]),
#    array([1197]),
#    array([1904]),
#    array([1052]),
#    array([1045]),
#    array([1038]),
#    array([1596]),
#    array([1589]),
#    array([1411]),
#    array([1291]),
#    array([1407]),
#    array([1877]),
#    array([966]),
#    array([1464]),
#    array([704]),
#    array([1109]),
#    array([1347]),
#    array([1756]),
#    array([1756]),
#    array([1042]),
#    array([1444]),
#    array([1741]),
#    array([1719]),
#    array([1217]),
#    array([1140]),
#    array([1878]),
#    array([705]),
#    array([1946]),
#    array([1414]),
#    array([602]),
#    array([1052]),
#    array([1295]),
#    array([1424]),
#    array([1359]),
#    array([1168]),
#    array([1097]),
#    array([691]),
#    array([1316]),
#    array([1276]),
#    array([1289]),
#    array([1293]),
#    array([1353]),
#    array([1132]),
#    array([1670]),
#    array([837]),
#    array([1550]),
#    array([1540]),
#    array([1256]),
#    array([1394]),
#    array([1341]),
#    array([1289]),
#    array([1112]),
#    array([2339]),
#    array([1468]),
#    array([1334]),
#    array([1457]),
#    array([1603]),
#    array([615]),
#    array([1068]),
#    array([1590]),
#    array([1531]),
#    array([1212]),
#    array([1237]),
#    array([1413]),
#    array([1516]),
#    array([1276]),
#    array([1564]),
#    array([1465]),
#    array([1286]),
#    array([1312]),
#    array([1673]),
#    array([1313]),
#    array([1609]),
#    array([1158]),
#    array([836]),
#    array([1289]),
#    array([1487]),
#    array([1259]),
#    array([1298]),
#    array([1226]),
#    array([1566]),
#    array([1022]),
#    array([1235]),
#    array([1951]),
#    array([1047]),
#    array([1342]),
#    array([1107]),
#    array([1251]),
#    array([1305]),
#    array([1388]),
#    array([1235]),
#    array([2089]),
#    array([1626]),
#    array([1111]),
#    array([1553]),
#    array([1064]),
#    array([1243]),
#    array([1659]),
#    array([1594]),
#    array([1268]),
#    array([1304]),
#    array([1368]),
#    array([720]),
#    array([1521]),
#    array([1137]),
#    array([978]),
#    array([1221]),
#    array([1565]),
#    array([1578]),
#    array([1493]),
#    array([1178]),
#    array([991]),
#    array([2560]),
#    array([1657]),
#    array([1204]),
#    array([673]),
#    array([1131]),
#    array([1576]),
#    array([1217]),
#    array([530]),
#    array([739]),
#    array([1617]),
#    array([1592]),
#    array([1343]),
#    array([1303]),
#    array([1351]),
#    array([1910]),
#    array([1298]),
#    array([1087]),
#    array([1439]),
#    array([1238]),
#    array([1716]),
#    array([1099]),
#    array([1058]),
#    array([1285]),
#    array([1651]),
#    array([1152]),
#    array([1767]),
#    array([1039]),
#    array([1130]),
#    array([1645]),
#    array([1413]),
#    array([1218]),
#    array([597]),
#    array([2184]),
#    array([1592]),
#    array([1388]),
#    array([757]),
#    array([1504]),
#    array([1503]),
#    array([1105]),
#    array([2398]),
#    array([1661]),
#    array([1421]),
#    array([999]),
#    array([1387]),
#    array([1243]),
#    array([1860]),
#    array([1502]),
#    array([1460]),
#    array([1348]),
#    array([1087]),
#    array([1226]),
#    array([1230]),
#    array([1555]),
#    array([1827]),
#    array([1376]),
#    array([1771]),
#    array([1873]),
#    array([1679]),
#    array([1002]),
#    array([1344]),
#    array([1461]),
#    array([760]),
#    array([1428]),
#    array([1777]),
#    array([1302]),
#    array([1483]),
#    array([1060]),
#    array([1330]),
#    array([1229]),
#    array([886]),
#    array([844]),
#    array([1450]),
#    array([2311]),
#    array([1378]),
#    array([1033]),
#    array([1523]),
#    array([1374]),
#    array([1080]),
#    array([1234]),
#    array([1600]),
#    array([1155]),
#    array([1353]),
#    array([1546]),
#    array([1590]),
#    array([1448]),
#    array([1271]),
#    array([1223]),
#    array([1117]),
#    array([994]),
#    array([1468]),
#    array([1658]),
#    array([1368]),
#    array([1218]),
#    array([702]),
#    array([1516]),
#    array([1310]),
#    array([1767]),
#    array([933]),
#    array([1512]),
#    array([829]),
#    array([1120]),
#    array([1506]),
#    array([1384]),
#    array([817]),
#    array([2094]),
#    array([815]),
#    array([510]),
#    array([1377]),
#    array([1193]),
#    array([1287]),
#    array([701]),
#    array([1770]),
#    array([1409]),
#    array([1354]),
#    array([1765]),
#    array([1192]),
#    array([687]),
#    array([1227]),
#    array([1737]),
#    array([1348]),
#    array([1435]),
#    array([1321]),
#    array([1479]),
#    array([1283]),
#    array([689]),
#    array([965]),
#    array([1541]),
#    array([1258]),
#    array([1339]),
#    array([1007]),
#    array([1387]),
#    array([960]),
#    array([1119]),
#    array([1642]),
#    array([1382]),
#    array([1232]),
#    array([1542]),
#    array([1094]),
#    array([1217]),
#    array([744]),
#    array([1614]),
#    array([1747]),
#    array([1144]),
#    array([1575]),
#    array([1463]),
#    array([1706]),
#    array([909]),
#    array([2434]),
#    array([1876]),
#    array([1000]),
#    array([1139]),
#    array([799]),
#    array([1881]),
#    array([1273]),
#    array([1328]),
#    array([1579]),
#    array([937]),
#    array([1749]),
#    array([1424]),
#    array([2011]),
#    array([1208]),
#    array([1259]),
#    array([1319]),
#    array([949]),
#    array([1338]),
#    array([1554]),
#    array([1350]),
#    array([1694]),
#    array([1678]),
#    array([2069]),
#    array([1222]),
#    array([1536]),
#    array([1400]),
#    array([1050]),
#    array([1389]),
#    array([1184]),
#    array([2093]),
#    array([678]),
#    array([1467]),
#    array([1219]),
#    array([1730]),
#    array([1025]),
#    array([1165]),
#    array([2133]),
#    array([1122]),
#    array([1083]),
#    array([1234]),
#    array([1277]),
#    array([1843]),
#    array([1747]),
#    array([1166]),
#    array([1326]),
#    array([1619]),
#    array([1285]),
#    array([1142]),
#    array([1190]),
#    array([1052]),
#    array([1628]),
#    array([1740]),
#    array([1378]),
#    array([996]),
#    array([1389]),
#    array([1365]),
#    array([1715]),
#    array([1582]),
#    array([1220]),
#    array([715]),
#    array([2552]),
#    array([1106]),
#    array([1731]),
#    array([1435]),
#    array([1882]),
#    array([2058]),
#    array([1658]),
#    array([1334]),
#    array([1441]),
#    array([1371]),
#    array([1991]),
#    array([1278]),
#    array([1734]),
#    array([1330]),
#    array([1787]),
#    array([1672]),
#    array([1439]),
#    array([1558]),
#    array([1795]),
#    array([893]),
#    array([1099]),
#    array([1408]),
#    array([1893]),
#    array([1151]),
#    array([1519]),
#    array([1245]),
#    array([1102]),
#    array([1402]),
#    array([1060]),
#    array([1459]),
#    array([1456]),
#    array([1439]),
#    array([1353]),
#    array([1173]),
#    array([1746]),
#    array([1279]),
#    array([1307]),
#    array([1473]),
#    array([1805]),
#    array([1421]),
#    array([1272]),
#    array([1409]),
#    array([647]),
#    array([1275]),
#    array([1270]),
#    array([1702]),
#    array([1256]),
#    array([3178]),
#    array([1626]),
#    array([1562]),
#    array([1960]),
#    array([1154]),
#    array([1629]),
#    array([1226]),
#    array([1743]),
#    array([1139]),
#    array([1073]),
#    array([683]),
#    array([1159]),
#    array([1859]),
#    array([1205]),
#    array([1409]),
#    array([1000]),
#    array([1209]),
#    array([1366]),
#    array([1161]),
#    array([1512]),
#    array([1750]),
#    array([1170]),
#    array([2218]),
#    array([1198]),
#    array([1329]),
#    array([857]),
#    array([1470]),
#    array([1435]),
#    array([1093]),
#    array([715]),
#    array([1512]),
#    array([2399]),
#    array([906]),
#    array([1052]),
#    array([975]),
#    array([783]),
#    array([990]),
#    array([1097]),
#    array([901]),
#    array([1327]),
#    array([1814]),
#    array([1365]),
#    array([1058]),
#    array([1476]),
#    array([1230]),
#    array([1581]),
#    array([1534]),
#    array([1612]),
#    array([1302]),
#    array([1439]),
#    array([1724]),
#    array([1784]),
#    array([1156]),
#    array([2556]),
#    array([1590]),
#    array([884]),
#    array([973]),
#    array([1447]),
#    array([1150]),
#    array([1193]),
#    array([706]),
#    array([1257]),
#    array([1303]),
#    array([1306]),
#    array([748]),
#    array([1774]),
#    array([1209]),
#    array([1074]),
#    array([1786]),
#    array([1456]),
#    array([1300]),
#    array([1470]),
#    array([715]),
#    array([1198]),
#    array([1556]),
#    array([1606]),
#    array([929]),
#    array([1606]),
#    array([1199]),
#    array([2400]),
#    array([1337]),
#    array([1270]),
#    array([654]),
#    array([1909]),
#    array([922]),
#    array([1158]),
#    array([1323]),
#    array([1025]),
#    array([1700]),
#    array([1628]),
#    array([1377]),
#    array([1517]),
#    array([1528]),
#    array([1329]),
#    array([1505]),
#    array([1172]),
#    array([1646]),
#    array([1693]),
#    array([1336]),
#    array([1289]),
#    array([1416]),
#    array([1608]),
#    array([1885]),
#    array([1744]),
#    array([1922]),
#    array([1448]),
#    array([1300]),
#    array([1366]),
#    array([1439]),
#    array([1241]),
#    array([1917]),
#    array([1391]),
#    array([1246]),
#    array([1248]),
#    array([1936]),
#    array([2375]),
#    array([1238]),
#    array([1626]),
#    array([791]),
#    array([1204]),
#    array([1300]),
#    array([1612]),
#    array([1071]),
#    array([1378]),
#    array([1100]),
#    array([2052]),
#    array([1349]),
#    array([1215]),
#    array([1149]),
#    array([2354]),
#    array([2644]),
#    array([918]),
#    array([1362]),
#    array([1222]),
#    array([1364]),
#    array([1463]),
#    array([1631]),
#    array([1878]),
#    array([1489]),
#    array([1437]),
#    array([1313]),
#    array([1290]),
#    array([1975]),
#    array([807]),
#    array([1438]),
#    array([1233]),
#    array([709]),
#    array([1597]),
#    array([1283]),
#    array([1101]),
#    array([1593]),
#    array([1631]),
#    array([2194]),
#    array([1128]),
#    array([1497]),
#    array([1385]),
#    array([1449]),
#    array([974]),
#    array([731]),
#    array([1191]),
#    array([1421]),
#    array([1256]),
#    array([1744]),
#    array([1766]),
#    array([2229]),
#    array([1773]),
#    array([1860]),
#    array([1179]),
#    array([906]),
#    array([2781]),
#    array([1650]),
#    array([1446]),
#    array([1703]),
#    array([761]),
#    array([1536]),
#    array([1373]),
#    array([1256]),
#    array([643]),
#    array([1215]),
#    array([2244]),
#    array([1409]),
#    array([1469]),
#    array([1847]),
#    array([1277]),
#    array([1227]),
#    array([1336]),
#    array([1110]),
#    array([1474]),
#    array([1955]),
#    array([660]),
#    array([888]),
#    array([1785]),
#    array([705]),
#    array([1211]),
#    array([1391]),
#    array([1407]),
#    array([1616]),
#    array([1498]),
#    array([1536]),
#    array([1594]),
#    array([1190]),
#    array([1248]),
#    array([827]),
#    array([920]),
#    array([1755]),
#    array([804]),
#    array([1196]),
#    array([850]),
#    array([1644]),
#    array([1749]),
#    array([2307]),
#    array([1757]),
#    array([1826]),
#    array([799]),
#    array([2121]),
#    array([1468]),
#    array([1482]),
#    array([1726]),
#    array([1806]),
#    array([1405]),
#    array([2052]),
#    array([1175]),
#    array([1786]),
#    array([1675]),
#    array([1200]),
#    array([1283]),
#    array([1937]),
#    array([2033]),
#    array([1915]),
#    array([1988]),
#    array([1648]),
#    array([1902]),
#    array([1454]),
#    array([838]),
#    array([1918]),
#    array([837]),
#    array([1567]),
#    array([1905]),
#    array([1422]),
#    array([1680]),
#    array([1652]),
#    array([1158]),
#    array([1797]),
#    array([1911]),
#    array([1260]),
#    array([1489]),
#    array([1794]),
#    array([1510]),
#    array([3231]),
#    array([1274]),
#    array([1572]),
#    array([1935]),
#    array([2187]),
#    array([1417]),
#    array([1465]),
#    array([1570]),
#    array([1445]),
#    array([694]),
#    array([1929]),
#    array([2447]),
#    array([1306]),
#    array([646]),
#    array([1236]),
#    array([2513]),
#    array([2091]),
#    array([854]),
#    array([1848]),
#    array([949]),
#    array([1371]),
#    array([1804]),
#    array([1605]),
#    array([1463]),
#    array([1279]),
#    array([1470]),
#    array([1265]),
#    array([2002]),
#    array([1475]),
#    array([1419]),
#    array([1628]),
#    array([1337]),
#    array([1135]),
#    array([1161]),
#    array([1571]),
#    array([1916]),
#    array([1346]),
#    array([805]),
#    array([1195]),
#    array([1155]),
#    array([1431]),
#    array([1194]),
#    array([1154]),
#    array([1232]),
#    array([1269]),
#    array([1742]),
#    array([1379]),
#    array([1870]),
#    array([1207]),
#    array([781]),
#    array([1773]),
#    array([864]),
#    array([1559]),
#    array([1830]),
#    array([1542]),
#    array([1506]),
#    array([1175]),
#    array([1383]),
#    array([1837]),
#    array([1191]),
#    array([1793]),
#    array([1560]),
#    array([1564]),
#    array([1843]),
#    array([2165]),
#    array([1631]),
#    array([1265]),
#    array([1455]),
#    array([1137]),
#    array([1367]),
#    array([1292]),
#    array([1682]),
#    array([1598]),
#    array([1555]),
#    array([2409]),
#    array([1770]),
#    array([1526]),
#    array([891]),
#    array([1756]),
#    array([1241]),
#    array([1681]),
#    array([1224]),
#    array([1572]),
#    array([1566]),
#    array([1579]),
#    array([1334]),
#    array([1230]),
#    array([767]),
#    array([724]),
#    array([1638]),
#    array([1349]),
#    array([1751]),
#    array([1414]),
#    array([1260]),
#    array([965]),
#    array([1121]),
#    array([1411]),
#    array([1602]),
#    array([1617]),
#    array([1244]),
#    array([1263]),
#    array([1036]),
#    array([1217]),
#    array([1556]),
#    array([2005]),
#    array([1698]),
#    array([2041]),
#    array([1102]),
#    array([1346]),
#    array([1511]),
#    array([1761]),
#    array([2117]),
#    array([596]),
#    array([2560]),
#    array([1409]),
#    array([1759]),
#    array([1886]),
#    array([915]),
#    array([1343]),
#    array([1870]),
#    array([1557]),
#    array([1824]),
#    array([1294]),
#    array([1545]),
#    array([820]),
#    array([1675]),
#    array([1678]),
#    array([2117]),
#    array([1721]),
#    array([1267]),
#    array([1562]),
#    array([1193]),
#    array([1254]),
#    array([1731]),
#    array([1099]),
#    array([747]),
#    array([1352]),
#    array([1770]),
#    array([1812]),
#    array([1673]),
#    array([2167]),
#    array([2369]),
#    array([1582]),
#    array([1800]),
#    array([1567]),
#    array([647]),
#    array([1447]),
#    array([1145]),
#    array([3280]),
#    array([1577]),
#    array([1140]),
#    array([1736]),
#    array([1436]),
#    array([1513]),
#    array([2505]),
#    array([1723]),
#    array([1695]),
#    array([1532]),
#    array([2110]),
#    array([1807]),
#    array([1687]),
#    array([1481]),
#    array([1318]),
#    array([1946]),
#    array([1481]),
#    array([2168]),
#    array([1583]),
#    array([1229]),
#    array([1718]),
#    array([1402]),
#    array([1127]),
#    array([1053]),
#    array([1340]),
#    array([732]),
#    array([2346]),
#    array([1580]),
#    array([1196]),
#    array([2086]),
#    array([1665]),
#    array([1495]),
#    array([2187]),
#    array([1371]),
#    array([1235]),
#    array([1556]),
#    array([1212]),
#    array([2701]),
#    array([1750]),
#    array([1610]),
#    array([2184]),
#    array([1745]),
#    array([1381]),
#    array([1793]),
#    array([1831]),
#    array([1468]),
#    array([1097]),
#    array([1682]),
#    array([1451]),
#    array([1509]),
#    array([1895]),
#    array([1403]),
#    array([1420]),
#    array([1717]),
#    array([1131]),
#    array([1005]),
#    array([948]),
#    array([1549]),
#    array([965]),
#    array([1958]),
#    array([1266]),
#    array([1367]),
#    array([1489]),
#    array([1582]),
#    array([2516]),
#    array([1557]),
#    array([1084]),
#    array([2583]),
#    array([1371]),
#    array([1537]),
#    array([1104]),
#    array([1482]),
#    array([1299]),
#    array([2167]),
#    array([1563]),
#    array([1772]),
#    array([1254]),
#    array([2229]),
#    array([2195]),
#    array([1362]),
#    array([2398]),
#    array([2649]),
#    array([1463]),
#    array([1174]),
#    array([1836]),
#    array([1817]),
#    array([1387]),
#    array([2028]),
#    array([1582]),
#    array([1774]),
#    array([1636]),
#    array([1031]),
#    array([916]),
#    array([1198]),
#    array([2189]),
#    array([1257]),
#    array([1503]),
#    array([1353]),
#    array([811]),
#    array([1270]),
#    array([1840]),
#    array([2585]),
#    array([1807]),
#    array([1729]),
#    array([1211]),
#    array([1763]),
#    array([1395]),
#    array([1843]),
#    array([1517]),
#    array([1977]),
#    array([2027]),
#    array([1497]),
#    array([1134]),
#    array([1483]),
#    array([1956]),
#    array([940]),
#    array([2183]),
#    array([2920]),
#    array([1221]),
#    array([1790]),
#    array([2005]),
#    array([1904]),
#    array([1647]),
#    array([1903]),
#    array([1564]),
#    array([1686]),
#    array([2412]),
#    array([2730]),
#    array([1361]),
#    array([821]),
#    array([938]),
#    array([1861]),
#    array([1345]),
#    array([2444]),
#    array([1686]),
#    array([1468]),
#    array([2320]),
#    array([1598]),
#    array([1232]),
#    array([1922]),
#    array([1355]),
#    array([2361]),
#    array([708]),
#    array([1687]),
#    array([1212]),
#    array([1752]),
#    array([1560]),
#    array([1520]),
#    array([1685]),
#    array([1678]),
#    array([1627]),
#    array([1637]),
#    array([1707]),
#    array([1208]),
#    array([1881]),
#    array([1360]),
#    array([1641]),
#    array([1820]),
#    array([1505]),
#    array([1627]),
#    array([1703]),
#    array([1433]),
#    array([2445]),
#    array([1665]),
#    array([1489]),
#    array([1393]),
#    array([1820]),
#    array([2742]),
#    array([1979]),
#    array([1378]),
#    array([1520]),
#    array([1588]),
#    array([1282]),
#    array([1872]),
#    array([2295]),
#    array([1065]),
#    array([1550]),
#    array([1527]),
#    array([1489]),
#    array([1264]),
#    array([1582]),
#    array([1567]),
#    array([1704]),
#    array([1546]),
#    array([1478]),
#    array([2132]),
#    array([1419]),
#    array([1065]),
#    array([1364]),
#    array([2247]),
#    array([1111]),
#    array([1836]),
#    array([1164]),
#    array([2005]),
#    array([1588]),
#    array([2242]),
#    array([1415]),
#    array([2483]),
#    array([1239]),
#    array([2057]),
#    array([1228]),
#    array([1629]),
#    array([2076]),
#    array([1231]),
#    array([1655]),
#    array([1477]),
#    array([1501]),
#    array([1313]),
#    array([2045]),
#    array([1448]),
#    array([858]),
#    array([1591]),
#    array([842]),
#    ...],
#   [array([4311]),
#    array([3753]),
#    array([3663]),
#    array([3490]),
#    array([3981]),
#    array([4027]),
#    array([3597]),
#    array([4088]),
#    array([4449]),
#    array([3946]),
#    array([3795]),
#    array([3567]),
#    array([4605]),
#    array([3530]),
#    array([3483]),
#    array([3951]),
#    array([3479]),
#    array([4563]),
#    array([3676]),
#    array([4686]),
#    array([3902]),
#    array([4291]),
#    array([3703]),
#    array([3891]),
#    array([3942]),
#    array([3994]),
#    array([3774]),
#    array([3503]),
#    array([4157]),
#    array([3753]),
#    array([4776]),
#    array([3784]),
#    array([4014]),
#    array([3725]),
#    array([3630]),
#    array([3519]),
#    array([3762]),
#    array([4107]),
#    array([3508]),
#    array([4148]),
#    array([3670]),
#    array([3891]),
#    array([4254]),
#    array([3700]),
#    array([4063]),
#    array([4542]),
#    array([4357]),
#    array([3910]),
#    array([3888]),
#    array([3783]),
#    array([4189]),
#    array([3762]),
#    array([3899]),
#    array([4303]),
#    array([3871]),
#    array([4642]),
#    array([3626]),
#    array([3764]),
#    array([4535]),
#    array([3598]),
#    array([4263]),
#    array([3709]),
#    array([3806]),
#    array([4345]),
#    array([4428]),
#    array([4149]),
#    array([4370]),
#    array([3546]),
#    array([3974]),
#    array([4085]),
#    array([4074]),
#    array([3982]),
#    array([4099]),
#    array([3814]),
#    array([3525]),
#    array([3580]),
#    array([4491]),
#    array([3699]),
#    array([4740]),
#    array([3829]),
#    array([4042]),
#    array([5029]),
#    array([4252]),
#    array([3738]),
#    array([3600]),
#    array([4822]),
#    array([3568]),
#    array([4121]),
#    array([3569]),
#    array([3542]),
#    array([4439]),
#    array([3656]),
#    array([3692]),
#    array([3575]),
#    array([5176]),
#    array([3956]),
#    array([3561]),
#    array([4150]),
#    array([3897]),
#    array([4316]),
#    array([3903]),
#    array([4040]),
#    array([4381]),
#    array([4166]),
#    array([3533]),
#    array([3927]),
#    array([3534]),
#    array([3524]),
#    array([3964]),
#    array([4129]),
#    array([3742]),
#    array([4160]),
#    array([3817]),
#    array([3921]),
#    array([3866]),
#    array([3937]),
#    array([3533]),
#    array([4165]),
#    array([3948]),
#    array([3999]),
#    array([3913]),
#    array([3814]),
#    array([4399]),
#    array([4075]),
#    array([3731]),
#    array([3732]),
#    array([3968]),
#    array([3915]),
#    array([3695]),
#    array([4098]),
#    array([3607]),
#    array([3625]),
#    array([4976]),
#    array([3929]),
#    array([3786]),
#    array([3591]),
#    array([4599]),
#    array([4549]),
#    array([3636]),
#    array([4066]),
#    array([4929]),
#    array([4101]),
#    array([3990]),
#    array([3553]),
#    array([4740]),
#    array([3732]),
#    array([3569]),
#    array([3502]),
#    array([4277]),
#    array([3951]),
#    array([3756]),
#    array([4294]),
#    array([4199]),
#    array([3942]),
#    array([3637]),
#    array([3563]),
#    array([3798]),
#    array([3504]),
#    array([3943]),
#    array([3928]),
#    array([3849]),
#    array([3925]),
#    array([4044]),
#    array([4222]),
#    array([4238]),
#    array([3658]),
#    array([3495]),
#    array([4314]),
#    array([4478]),
#    array([4089]),
#    array([3591]),
#    array([4221]),
#    array([3982]),
#    array([3825]),
#    array([4077]),
#    array([4014]),
#    array([4251]),
#    array([3683]),
#    array([4010]),
#    array([3676]),
#    array([3927]),
#    array([4470]),
#    array([3640]),
#    array([3948]),
#    array([3739]),
#    array([4143]),
#    array([4248]),
#    array([4084]),
#    array([3650]),
#    array([3750]),
#    array([4224]),
#    array([3651]),
#    array([4454]),
#    array([4100]),
#    array([3593]),
#    array([3886]),
#    array([3656]),
#    array([3811]),
#    array([4071]),
#    array([4134]),
#    array([4422]),
#    array([3920]),
#    array([4068]),
#    array([4558]),
#    array([3661]),
#    array([4199]),
#    array([3489]),
#    array([3897]),
#    array([3577]),
#    array([4297]),
#    array([4023]),
#    array([3978]),
#    array([3855]),
#    array([4050]),
#    array([4755]),
#    array([4136]),
#    array([4614]),
#    array([4095]),
#    array([4462]),
#    array([4740]),
#    array([4533]),
#    array([3698]),
#    array([3514]),
#    array([4160]),
#    array([3607]),
#    array([4256]),
#    array([3522]),
#    array([4172]),
#    array([4890]),
#    array([3784]),
#    array([3640]),
#    array([3602]),
#    array([3542]),
#    array([3777]),
#    array([3556]),
#    array([3625]),
#    array([4444]),
#    array([4293]),
#    array([3752]),
#    array([3550]),
#    array([3986]),
#    array([4632]),
#    array([3560]),
#    array([3939]),
#    array([3982]),
#    array([3519]),
#    array([3731]),
#    array([3912]),
#    array([3612]),
#    array([3530]),
#    array([4028]),
#    array([3815]),
#    array([4208]),
#    array([4758]),
#    array([3938]),
#    array([3748]),
#    array([4253]),
#    array([3472]),
#    array([4456]),
#    array([3848]),
#    array([4433]),
#    array([4544]),
#    array([3595]),
#    array([3758]),
#    array([4029]),
#    array([3754]),
#    array([3825]),
#    array([4071]),
#    array([4659]),
#    array([4251]),
#    array([4037]),
#    array([3660]),
#    array([3650]),
#    array([4274]),
#    array([3474]),
#    array([4548]),
#    array([3792]),
#    array([3503]),
#    array([3646]),
#    array([3584]),
#    array([3789]),
#    array([4542]),
#    array([4175]),
#    array([5054]),
#    array([4288]),
#    array([3787]),
#    array([4178]),
#    array([3596]),
#    array([4458]),
#    array([4422]),
#    array([3511]),
#    array([3776]),
#    array([4312]),
#    array([5169]),
#    array([3730]),
#    array([4895]),
#    array([4034]),
#    array([4112]),
#    array([4314]),
#    array([3809]),
#    array([4276]),
#    array([4092]),
#    array([3704]),
#    array([4109]),
#    array([3723]),
#    array([4719]),
#    array([3996]),
#    array([3775]),
#    array([3571]),
#    array([4228]),
#    array([4017]),
#    array([4127]),
#    array([3766]),
#    array([3632]),
#    array([4079]),
#    array([3830]),
#    array([4047]),
#    array([3520]),
#    array([3772]),
#    array([4836]),
#    array([3669]),
#    array([3543]),
#    array([3812]),
#    array([4212]),
#    array([3851]),
#    array([4421]),
#    array([4253]),
#    array([3737]),
#    array([3533]),
#    array([3829]),
#    array([3811]),
#    array([3952]),
#    array([4550]),
#    array([4039]),
#    array([3653]),
#    array([4077]),
#    array([3975]),
#    array([3717]),
#    array([4820]),
#    array([4409]),
#    array([3688]),
#    array([3974]),
#    array([4065]),
#    array([4095]),
#    array([4163]),
#    array([3658]),
#    array([4498]),
#    array([3906]),
#    array([4456]),
#    array([4503]),
#    array([3704]),
#    array([3788]),
#    array([3966]),
#    array([3651]),
#    array([3526]),
#    array([4270]),
#    array([4255]),
#    array([3914]),
#    array([3494]),
#    array([4046]),
#    array([3696]),
#    array([4272]),
#    array([3838]),
#    array([4960]),
#    array([4382]),
#    array([4216]),
#    array([3853]),
#    array([3534]),
#    array([4202]),
#    array([3914]),
#    array([3654]),
#    array([4631]),
#    array([4197]),
#    array([4372]),
#    array([4526]),
#    array([4003]),
#    array([4269]),
#    array([3997]),
#    array([3639]),
#    array([3549]),
#    array([4496]),
#    array([4178]),
#    array([4123]),
#    array([4059]),
#    array([3582]),
#    array([3607]),
#    array([3697]),
#    array([4014]),
#    array([4630]),
#    array([3880]),
#    array([4191]),
#    array([5004]),
#    array([5554]),
#    array([4180]),
#    array([3896]),
#    array([3718]),
#    array([3780]),
#    array([3507]),
#    array([4232]),
#    array([3890]),
#    array([3516]),
#    array([3628]),
#    array([3819]),
#    array([3769]),
#    array([3536]),
#    array([3711]),
#    array([4772]),
#    array([4487]),
#    array([3755]),
#    array([3713]),
#    array([4259]),
#    array([3908]),
#    array([4065]),
#    array([3774]),
#    array([4712]),
#    array([4255]),
#    array([4281]),
#    array([3523]),
#    array([3967]),
#    array([4629]),
#    array([3825]),
#    array([3592]),
#    array([4107]),
#    array([4558]),
#    array([4064]),
#    array([4200]),
#    array([3863]),
#    array([4579]),
#    array([4449]),
#    array([3769]),
#    array([4439]),
#    array([4712]),
#    array([4351]),
#    array([3610]),
#    array([3675]),
#    array([4505]),
#    array([3492]),
#    array([4154]),
#    array([3699]),
#    array([3566]),
#    array([4098]),
#    array([3576]),
#    array([3756]),
#    array([3527]),
#    array([3817]),
#    array([4345]),
#    array([3754]),
#    array([4422]),
#    array([3572]),
#    array([3838]),
#    array([4101]),
#    array([4252]),
#    array([3557]),
#    array([4006]),
#    array([4063]),
#    array([5274]),
#    array([4437]),
#    array([3578]),
#    array([4430]),
#    array([3490]),
#    array([4249]),
#    array([4072]),
#    array([4435]),
#    array([3896]),
#    array([4100]),
#    array([3495]),
#    array([3935]),
#    array([3632]),
#    array([3839]),
#    array([4364]),
#    array([3481]),
#    array([3660]),
#    array([4006]),
#    array([3874]),
#    array([3766]),
#    array([3537]),
#    array([3492]),
#    array([3535]),
#    array([4095]),
#    array([4256]),
#    array([4247]),
#    array([3868]),
#    array([4676]),
#    array([4547]),
#    array([4583]),
#    array([3890]),
#    array([3818]),
#    array([4175]),
#    array([4529]),
#    array([4048]),
#    array([4614]),
#    array([3749]),
#    array([4010]),
#    array([3525]),
#    array([3752]),
#    array([3634]),
#    array([4065]),
#    array([4140]),
#    array([4527]),
#    array([4306]),
#    array([3488]),
#    array([4227]),
#    array([4077]),
#    array([3885]),
#    array([4343]),
#    array([3782]),
#    array([4697]),
#    array([3817]),
#    array([4509]),
#    array([4150]),
#    array([4123]),
#    array([4145]),
#    array([4225]),
#    array([3534]),
#    array([3918]),
#    array([3497]),
#    array([4620]),
#    array([3962]),
#    array([4222]),
#    array([3784]),
#    array([3835]),
#    array([5244]),
#    array([4650]),
#    array([4042]),
#    array([3585]),
#    array([3928]),
#    array([3504]),
#    array([3993]),
#    array([4317]),
#    array([4511]),
#    array([3722]),
#    array([4037]),
#    array([4155]),
#    array([4182]),
#    array([4033]),
#    array([3973]),
#    array([3535]),
#    array([3647]),
#    array([3966]),
#    array([4458]),
#    array([3975]),
#    array([3855]),
#    array([3833]),
#    array([3493]),
#    array([4041]),
#    array([3749]),
#    array([4051]),
#    array([4864]),
#    array([3799]),
#    array([4007]),
#    array([3652]),
#    array([4246]),
#    array([4138]),
#    array([3687]),
#    array([4587]),
#    array([3771]),
#    array([3693]),
#    array([3512]),
#    array([3609]),
#    array([4944]),
#    array([4247]),
#    array([4048]),
#    array([4038]),
#    array([4045]),
#    array([3778]),
#    array([4002]),
#    array([3657]),
#    array([4571]),
#    array([3927]),
#    array([3820]),
#    array([3680]),
#    array([3487]),
#    array([3527]),
#    array([4119]),
#    array([4869]),
#    array([4134]),
#    array([4217]),
#    array([3489]),
#    array([3562]),
#    array([3899]),
#    array([4253]),
#    array([4119]),
#    array([4313]),
#    array([3906]),
#    array([3838]),
#    array([3937]),
#    array([4759]),
#    array([3889]),
#    array([4406]),
#    array([3593]),
#    array([4417]),
#    array([3982]),
#    array([3630]),
#    array([4355]),
#    array([3711]),
#    array([3808]),
#    array([3961]),
#    array([3988]),
#    array([3644]),
#    array([4738]),
#    array([4070]),
#    array([4184]),
#    array([3971]),
#    array([3756]),
#    array([4101]),
#    array([4098]),
#    array([4666]),
#    array([4082]),
#    array([3543]),
#    array([4401]),
#    array([4371]),
#    array([4050]),
#    array([3944]),
#    array([3982]),
#    array([4106]),
#    array([3781]),
#    array([3684]),
#    array([4608]),
#    array([5103]),
#    array([4337]),
#    array([3889]),
#    array([3783]),
#    array([3816]),
#    array([3491]),
#    array([3598]),
#    array([3929]),
#    array([4518]),
#    array([3626]),
#    array([3819]),
#    array([4449]),
#    array([4419]),
#    array([4962]),
#    array([3651]),
#    array([4449]),
#    array([4546]),
#    array([4099]),
#    array([3505]),
#    array([3803]),
#    array([4926]),
#    array([4650]),
#    array([3996]),
#    array([3635]),
#    array([4253]),
#    array([3734]),
#    array([3563]),
#    array([4416]),
#    array([3608]),
#    array([4039]),
#    array([4177]),
#    array([4201]),
#    array([3660]),
#    array([4422]),
#    array([4099]),
#    array([3758]),
#    array([4447]),
#    array([3848]),
#    array([4254]),
#    array([3707]),
#    array([3736]),
#    array([4742]),
#    array([3618]),
#    array([3685]),
#    array([4050]),
#    array([4087]),
#    array([4488]),
#    array([3749]),
#    array([4379]),
#    array([4247]),
#    array([4077]),
#    array([3491]),
#    array([3779]),
#    array([4951]),
#    array([3636]),
#    array([4590]),
#    array([4427]),
#    array([4026]),
#    array([3850]),
#    array([4686]),
#    array([4795]),
#    array([4092]),
#    array([3848]),
#    array([3627]),
#    array([3861]),
#    array([4227]),
#    array([3941]),
#    array([4524]),
#    array([3616]),
#    array([4056]),
#    array([3988]),
#    array([4835]),
#    array([4613]),
#    array([3724]),
#    array([4739]),
#    array([5100]),
#    array([4328]),
#    array([3477]),
#    array([3691]),
#    array([4828]),
#    array([4021]),
#    array([4587]),
#    array([4410]),
#    array([4959]),
#    array([4961]),
#    array([4889]),
#    array([4134]),
#    array([4218]),
#    array([4018]),
#    array([3498]),
#    array([4080]),
#    array([4425]),
#    array([4141]),
#    array([4689]),
#    array([3790]),
#    array([3886]),
#    array([4160]),
#    array([4296]),
#    array([3819]),
#    array([4654]),
#    array([3521]),
#    array([3740]),
#    array([3990]),
#    array([4869]),
#    array([4307]),
#    array([4061]),
#    array([3992]),
#    array([3609]),
#    array([3595]),
#    array([3700]),
#    array([3651]),
#    array([4596]),
#    array([4148]),
#    array([3634]),
#    array([4047]),
#    array([3687]),
#    array([4402]),
#    array([4391]),
#    array([3802]),
#    array([3880]),
#    array([3949]),
#    array([4839]),
#    array([4187]),
#    array([4340]),
#    array([4072]),
#    array([3950]),
#    array([3646]),
#    array([4079]),
#    array([4558]),
#    array([4347]),
#    array([4263]),
#    array([3636]),
#    array([4323]),
#    array([3972]),
#    array([3891]),
#    array([3547]),
#    array([4387]),
#    array([4181]),
#    array([4311]),
#    array([3776]),
#    array([3877]),
#    array([4028]),
#    array([4612]),
#    array([3831]),
#    array([3853]),
#    array([3548]),
#    array([3943]),
#    array([4062]),
#    array([4419]),
#    array([4979]),
#    array([4100]),
#    array([3769]),
#    array([3858]),
#    array([3645]),
#    array([5328]),
#    array([4161]),
#    array([4590]),
#    array([4406]),
#    array([4066]),
#    array([4552]),
#    array([3825]),
#    array([4390]),
#    array([4855]),
#    array([3953]),
#    array([3512]),
#    array([4241]),
#    array([3710]),
#    array([4442]),
#    array([4020]),
#    array([4717]),
#    array([4036]),
#    array([4814]),
#    array([4275]),
#    array([4196]),
#    array([4177]),
#    array([4755]),
#    array([4802]),
#    array([4335]),
#    array([4435]),
#    array([3811]),
#    array([4876]),
#    array([3877]),
#    array([3943]),
#    array([3490]),
#    array([4599]),
#    array([4374]),
#    array([4172]),
#    array([3798]),
#    array([4268]),
#    array([3677]),
#    array([3910]),
#    array([3642]),
#    array([3760]),
#    array([3918]),
#    array([4331]),
#    array([4844]),
#    array([4003]),
#    array([3939]),
#    array([3920]),
#    array([3945]),
#    array([4641]),
#    array([3503]),
#    array([3475]),
#    array([3690]),
#    array([4137]),
#    array([4007]),
#    array([4528]),
#    array([4337]),
#    array([4128]),
#    array([3555]),
#    array([3889]),
#    array([3998]),
#    array([5228]),
#    array([4295]),
#    array([3523]),
#    array([4613]),
#    array([5146]),
#    array([3829]),
#    array([4539]),
#    array([4597]),
#    array([4323]),
#    array([4030]),
#    array([4451]),
#    array([3904]),
#    array([3924]),
#    array([4240]),
#    array([4792]),
#    array([4557]),
#    array([4361]),
#    array([4964]),
#    array([4136]),
#    array([4089]),
#    array([4932]),
#    array([4730]),
#    array([4054]),
#    array([5211]),
#    array([4100]),
#    array([4030]),
#    array([4326]),
#    array([4831]),
#    array([4200]),
#    array([4379]),
#    array([4156]),
#    array([4157]),
#    array([3646]),
#    array([3709]),
#    array([4241]),
#    array([3822]),
#    array([3873]),
#    array([3914]),
#    array([5158]),
#    array([4142]),
#    array([4206]),
#    array([4272]),
#    array([4113]),
#    array([4655]),
#    array([4647]),
#    array([4333]),
#    array([4306]),
#    array([3789]),
#    array([4226]),
#    array([4401]),
#    array([4150]),
#    array([4422]),
#    array([4274]),
#    array([3520]),
#    array([4220]),
#    array([4233]),
#    array([4114]),
#    array([3529]),
#    array([4134]),
#    array([4421]),
#    array([4455]),
#    array([3942]),
#    array([3756]),
#    array([4503]),
#    array([4218]),
#    array([5237]),
#    array([4106]),
#    array([4389]),
#    array([4465]),
#    array([4024]),
#    array([4171]),
#    array([4434]),
#    array([4671]),
#    array([3779]),
#    array([4382]),
#    array([4533]),
#    array([3718]),
#    array([3495]),
#    array([4228]),
#    array([4713]),
#    array([3587]),
#    array([4421]),
#    array([4583]),
#    array([5224]),
#    array([4053]),
#    array([4239]),
#    array([3598]),
#    array([4010]),
#    array([3953]),
#    array([4734]),
#    array([4626]),
#    array([4256]),
#    array([4313]),
#    array([4551]),
#    array([5428]),
#    array([4305]),
#    array([4450]),
#    array([4269]),
#    array([4673]),
#    array([4134]),
#    array([3740]),
#    array([4022]),
#    array([4342]),
#    array([5031]),
#    array([4768]),
#    array([4027]),
#    array([3475]),
#    array([3673]),
#    array([4611]),
#    array([3504]),
#    array([3778]),
#    array([4812]),
#    array([3734]),
#    array([4674]),
#    array([4430]),
#    array([5189]),
#    array([4006]),
#    array([4455]),
#    array([4128]),
#    array([4286]),
#    array([4436]),
#    array([4183]),
#    array([3766]),
#    array([4058]),
#    array([5007]),
#    array([3900]),
#    array([4037]),
#    array([4564]),
#    array([4288]),
#    array([4004]),
#    array([3553]),
#    array([3631]),
#    array([4668]),
#    array([4070]),
#    array([4223]),
#    array([4921]),
#    array([4530]),
#    array([4273]),
#    array([3748]),
#    array([3880]),
#    array([5001]),
#    array([4375]),
#    array([3918]),
#    array([4042]),
#    array([4246]),
#    array([4546]),
#    array([4205]),
#    array([4804]),
#    array([5154]),
#    array([4745]),
#    array([3496]),
#    array([4418]),
#    array([4501]),
#    array([4887]),
#    array([5320]),
#    array([4615]),
#    array([4487]),
#    array([4041]),
#    array([4169]),
#    array([5212]),
#    array([3887]),
#    array([3870]),
#    array([3879]),
#    array([3875]),
#    array([4253]),
#    array([3744]),
#    array([3837]),
#    array([3561]),
#    array([4392]),
#    array([3763]),
#    ...],
#   [array([12535]),
#    array([13794]),
#    array([14771]),
#    array([14373]),
#    array([13173]),
#    array([13363]),
#    array([12956]),
#    array([15139]),
#    array([14132]),
#    array([13015]),
#    array([15511]),
#    array([14833]),
#    array([13630]),
#    array([14213]),
#    array([14276]),
#    array([14264]),
#    array([15423]),
#    array([13400]),
#    array([14965]),
#    array([12871]),
#    array([13945]),
#    array([15200]),
#    array([11603]),
#    array([13820]),
#    array([12603]),
#    array([12478]),
#    array([14334]),
#    array([12403]),
#    array([14576]),
#    array([13324]),
#    array([14465]),
#    array([14567]),
#    array([12896]),
#    array([13360]),
#    array([13787]),
#    array([13677]),
#    array([13119]),
#    array([15106]),
#    array([14084]),
#    array([15078]),
#    array([13670]),
#    array([13719]),
#    array([14603]),
#    array([15019]),
#    array([14954]),
#    array([14490]),
#    array([14242]),
#    array([12429]),
#    array([13970]),
#    array([14426]),
#    array([12592]),
#    array([13109]),
#    array([12631]),
#    array([13090]),
#    array([15203]),
#    array([13179]),
#    array([14901]),
#    array([12593]),
#    array([13452]),
#    array([14533]),
#    array([12510]),
#    array([15578]),
#    array([14880]),
#    array([13653]),
#    array([14107]),
#    array([14223]),
#    array([13791]),
#    array([14137]),
#    array([14319]),
#    array([12257]),
#    array([13124]),
#    array([13212]),
#    array([14244]),
#    array([13303]),
#    array([17064]),
#    array([13598]),
#    array([15209]),
#    array([16171]),
#    array([14991]),
#    array([15077]),
#    array([16202]),
#    array([14703]),
#    array([13280]),
#    array([15039]),
#    array([13997]),
#    array([13866]),
#    array([13847]),
#    array([14955]),
#    array([14615]),
#    array([13764]),
#    array([13945]),
#    array([15091]),
#    array([13627]),
#    array([14252]),
#    array([13376]),
#    array([15391]),
#    array([13740]),
#    array([12867]),
#    array([14844]),
#    array([15079]),
#    array([15549]),
#    array([13092]),
#    array([12941]),
#    array([13681]),
#    array([14455]),
#    array([13672]),
#    array([13854]),
#    array([14308]),
#    array([13753]),
#    array([14071]),
#    array([15180]),
#    array([13090]),
#    array([12777]),
#    array([15738]),
#    array([14557]),
#    array([13678]),
#    array([14743]),
#    array([14082]),
#    array([14119]),
#    array([14149]),
#    array([13758]),
#    array([13617]),
#    array([14326]),
#    array([16161]),
#    array([14716]),
#    array([15999]),
#    array([13830]),
#    array([12025]),
#    array([13988]),
#    array([14511]),
#    array([14074]),
#    array([12906]),
#    array([13142]),
#    array([14465]),
#    array([13816]),
#    array([14696]),
#    array([13138]),
#    array([15121]),
#    array([14544]),
#    array([14747]),
#    array([12980]),
#    array([14643]),
#    array([15473]),
#    array([14428]),
#    array([15033]),
#    array([14624]),
#    array([12493]),
#    array([13085]),
#    array([15527]),
#    array([13814]),
#    array([15102]),
#    array([14414]),
#    array([13177]),
#    array([14748]),
#    array([14084]),
#    array([13781]),
#    array([14779]),
#    array([14042]),
#    array([14330]),
#    array([14474]),
#    array([17628]),
#    array([12739]),
#    array([14500]),
#    array([15236]),
#    array([15634]),
#    array([13534]),
#    array([13062]),
#    array([15571]),
#    array([13633]),
#    array([14185]),
#    array([13345]),
#    array([16485]),
#    array([15331]),
#    array([14934]),
#    array([14441]),
#    array([13796]),
#    array([14511]),
#    array([14802]),
#    array([13931]),
#    array([13016]),
#    array([15552]),
#    array([12576]),
#    array([14381]),
#    array([13991]),
#    array([16428]),
#    array([13139]),
#    array([15869]),
#    array([15472]),
#    array([15301]),
#    array([12779]),
#    array([14212]),
#    array([15584]),
#    array([15982]),
#    array([15172]),
#    array([14593]),
#    array([14474]),
#    array([14336]),
#    array([13140]),
#    array([14230]),
#    array([13247]),
#    array([14305]),
#    array([14952]),
#    array([14418]),
#    array([14270]),
#    array([15867]),
#    array([15315]),
#    array([14229]),
#    array([13021]),
#    array([14279]),
#    array([13767]),
#    array([14324]),
#    array([12595]),
#    array([13819]),
#    array([14354]),
#    array([14830]),
#    array([16422]),
#    array([13557]),
#    array([16216]),
#    array([15039]),
#    array([14887]),
#    array([13720]),
#    array([13692]),
#    array([14593]),
#    array([14763]),
#    array([13648]),
#    array([14727]),
#    array([13503]),
#    array([13311]),
#    array([14755]),
#    array([14802]),
#    array([13769]),
#    array([14393]),
#    array([14625]),
#    array([14402]),
#    array([15282]),
#    array([15293]),
#    array([13751]),
#    array([14181]),
#    array([13209]),
#    array([14437]),
#    array([13513]),
#    array([13083]),
#    array([12192]),
#    array([15028]),
#    array([14948]),
#    array([14109]),
#    array([14459]),
#    array([14103]),
#    array([15958]),
#    array([13041]),
#    array([14204]),
#    array([15508]),
#    array([15581]),
#    array([14955]),
#    array([15478]),
#    array([12847]),
#    array([14626]),
#    array([10201]),
#    array([13299]),
#    array([13545]),
#    array([13853]),
#    array([14969]),
#    array([13958]),
#    array([13746]),
#    array([12489]),
#    array([13980]),
#    array([13730]),
#    array([14224]),
#    array([14080]),
#    array([14238]),
#    array([14932]),
#    array([14731]),
#    array([15195]),
#    array([14218]),
#    array([16033]),
#    array([15738]),
#    array([15645]),
#    array([15754]),
#    array([14912]),
#    array([13625]),
#    array([14926]),
#    array([14327]),
#    array([14133]),
#    array([13971]),
#    array([14783]),
#    array([14289]),
#    array([14618]),
#    array([13234]),
#    array([16059]),
#    array([14227]),
#    array([13270]),
#    array([13432]),
#    array([14211]),
#    array([14054]),
#    array([15367]),
#    array([14532]),
#    array([14341]),
#    array([13545]),
#    array([14235]),
#    array([13820]),
#    array([15451]),
#    array([13505]),
#    array([13836]),
#    array([13159]),
#    array([15657]),
#    array([15005]),
#    array([15824]),
#    array([16220]),
#    array([14730]),
#    array([14463]),
#    array([15367]),
#    array([14397]),
#    array([13360]),
#    array([15071]),
#    array([16605]),
#    array([13339]),
#    array([13082]),
#    array([15143]),
#    array([14450]),
#    array([15445]),
#    array([13578]),
#    array([14381]),
#    array([13432]),
#    array([14678]),
#    array([14220]),
#    array([13803]),
#    array([14198]),
#    array([13152]),
#    array([13306]),
#    array([14672]),
#    array([14023]),
#    array([15513]),
#    array([14667]),
#    array([14036]),
#    array([14351]),
#    array([16541]),
#    array([16373]),
#    array([15798]),
#    array([14280]),
#    array([13849]),
#    array([13289]),
#    array([15225]),
#    array([15190]),
#    array([14215]),
#    array([13930]),
#    array([16208]),
#    array([14551]),
#    array([15034]),
#    array([14436]),
#    array([12878]),
#    array([15615]),
#    array([15514]),
#    array([14545]),
#    array([15710]),
#    array([13939]),
#    array([14892]),
#    array([15785]),
#    array([14994]),
#    array([15281]),
#    array([15497]),
#    array([15574]),
#    array([15215]),
#    array([16493]),
#    array([15211]),
#    array([13614]),
#    array([14161]),
#    array([16101]),
#    array([17634]),
#    array([16732]),
#    array([13345]),
#    array([14230]),
#    array([13784]),
#    array([15554]),
#    array([16132]),
#    array([13120]),
#    array([13392]),
#    array([13674]),
#    array([16500]),
#    array([13113]),
#    array([13420]),
#    array([15005]),
#    array([13355]),
#    array([13781]),
#    array([15443]),
#    array([14222]),
#    array([14666]),
#    array([13722]),
#    array([14585]),
#    array([12920]),
#    array([15552]),
#    array([16730]),
#    array([16089]),
#    array([15048]),
#    array([13804]),
#    array([14256]),
#    array([15305]),
#    array([13609]),
#    array([15352]),
#    array([17390]),
#    array([15290]),
#    array([17258]),
#    array([14018]),
#    array([16258]),
#    array([14401]),
#    array([16369]),
#    array([15199]),
#    array([15152]),
#    array([15214]),
#    array([14432]),
#    array([15573]),
#    array([14807]),
#    array([15162]),
#    array([15140]),
#    array([14732]),
#    array([14037]),
#    array([14364]),
#    array([13174]),
#    array([15130]),
#    array([14524]),
#    array([13992]),
#    array([15060]),
#    array([14475]),
#    array([14287]),
#    array([15312]),
#    array([13989]),
#    array([14192]),
#    array([14378]),
#    array([14576]),
#    array([13583]),
#    array([14212]),
#    array([15751]),
#    array([14792]),
#    array([14826]),
#    array([15108]),
#    array([13967]),
#    array([13977]),
#    array([13956]),
#    array([9865]),
#    array([13575]),
#    array([13300]),
#    array([15347]),
#    array([14863]),
#    array([15530]),
#    array([12841]),
#    array([14917]),
#    array([16027]),
#    array([15212]),
#    array([14111]),
#    array([14375]),
#    array([16377]),
#    array([14781]),
#    array([17350]),
#    array([14205]),
#    array([13204]),
#    array([14805]),
#    array([14187]),
#    array([13377]),
#    array([14637]),
#    array([14540]),
#    array([14881]),
#    array([14719]),
#    array([14357]),
#    array([14127]),
#    array([14567]),
#    array([16359]),
#    array([14812]),
#    array([16464]),
#    array([14512]),
#    array([14463]),
#    array([15180]),
#    array([15157]),
#    array([14257]),
#    array([15058]),
#    array([14160]),
#    array([13671]),
#    array([13819]),
#    array([14321]),
#    array([15925]),
#    array([16908]),
#    array([14374]),
#    array([14378]),
#    array([15110]),
#    array([13434]),
#    array([14738]),
#    array([15860]),
#    array([15495]),
#    array([14471]),
#    array([15763]),
#    array([14802]),
#    array([14220]),
#    array([14544]),
#    array([12042]),
#    array([14565]),
#    array([16695]),
#    array([14178]),
#    array([15670]),
#    array([16339]),
#    array([15226]),
#    array([13264]),
#    array([15017]),
#    array([14973]),
#    array([14750]),
#    array([15505]),
#    array([16563]),
#    array([15740]),
#    array([15471]),
#    array([13810]),
#    array([14949]),
#    array([15053]),
#    array([13647]),
#    array([12575]),
#    array([9819]),
#    array([14330]),
#    array([15886]),
#    array([14781]),
#    array([14521]),
#    array([15594]),
#    array([14762]),
#    array([13117]),
#    array([14649]),
#    array([13604]),
#    array([15475]),
#    array([15473]),
#    array([13937]),
#    array([14202]),
#    array([14893]),
#    array([15862]),
#    array([16824]),
#    array([15149]),
#    array([10211]),
#    array([15063]),
#    array([15580]),
#    array([14970]),
#    array([13563]),
#    array([13966]),
#    array([14287]),
#    array([16207]),
#    array([15050]),
#    array([15691]),
#    array([14515]),
#    array([15372]),
#    array([14112]),
#    array([14049]),
#    array([16237]),
#    array([16736]),
#    array([16692]),
#    array([14769]),
#    array([15240]),
#    array([15124]),
#    array([14145]),
#    array([14738]),
#    array([14885]),
#    array([15560]),
#    array([15584]),
#    array([15802]),
#    array([16230]),
#    array([15041]),
#    array([16712]),
#    array([15611]),
#    array([15572]),
#    array([14791]),
#    array([14786]),
#    array([14709]),
#    array([15026]),
#    array([13988]),
#    array([13999]),
#    array([14728]),
#    array([15559]),
#    array([14954]),
#    array([17038]),
#    array([15903]),
#    array([16856]),
#    array([9980]),
#    array([14829]),
#    array([14751]),
#    array([14314]),
#    array([14220]),
#    array([15683]),
#    array([16019]),
#    array([14335]),
#    array([14470]),
#    array([15678]),
#    array([13891]),
#    array([15442]),
#    array([15200]),
#    array([13784]),
#    array([13804]),
#    array([13697]),
#    array([13517]),
#    array([14738]),
#    array([15635]),
#    array([16023]),
#    array([16557]),
#    array([15817]),
#    array([15260]),
#    array([14134]),
#    array([15237]),
#    array([14319]),
#    array([15627]),
#    array([13908]),
#    array([13845]),
#    array([15926]),
#    array([15054]),
#    array([15656]),
#    array([16606]),
#    array([16328]),
#    array([15427]),
#    array([15313]),
#    array([15154]),
#    array([14261]),
#    array([15998]),
#    array([16078]),
#    array([16236]),
#    array([14596]),
#    array([16469]),
#    array([14571]),
#    array([15195]),
#    array([16401]),
#    array([16258]),
#    array([13988]),
#    array([14257]),
#    array([14103]),
#    array([13222]),
#    array([14043]),
#    array([13783]),
#    array([14485]),
#    array([15338]),
#    array([10583]),
#    array([13785]),
#    array([16461]),
#    array([16256]),
#    array([15243]),
#    array([15903]),
#    array([14662]),
#    array([15399]),
#    array([15772]),
#    array([13756]),
#    array([15097]),
#    array([18484]),
#    array([15033]),
#    array([14651]),
#    array([15335]),
#    array([10156]),
#    array([14641]),
#    array([15004]),
#    array([14731]),
#    array([14994]),
#    array([13969]),
#    array([9867]),
#    array([16392]),
#    array([14209]),
#    array([15559]),
#    array([15075]),
#    array([15013]),
#    array([13148]),
#    array([15851]),
#    array([15059]),
#    array([14713]),
#    array([13986]),
#    array([15240]),
#    array([16252]),
#    array([14651]),
#    array([14409]),
#    array([15709]),
#    array([15095]),
#    array([14999]),
#    array([15151]),
#    array([13643]),
#    array([14838]),
#    array([14304]),
#    array([16423]),
#    array([14268]),
#    array([14728]),
#    array([16266]),
#    array([13703]),
#    array([15311]),
#    array([15134]),
#    array([16579]),
#    array([14542]),
#    array([14340]),
#    array([15148]),
#    array([16191]),
#    array([17119]),
#    array([13588]),
#    array([17437]),
#    array([14840]),
#    array([14614]),
#    array([13759]),
#    array([15872]),
#    array([15467]),
#    array([16100]),
#    array([15176]),
#    array([16179]),
#    array([15279]),
#    array([14977]),
#    array([15865]),
#    array([14950]),
#    array([14641]),
#    array([14719]),
#    array([15163]),
#    array([14969]),
#    array([15853]),
#    array([16937]),
#    array([14321]),
#    array([15111]),
#    array([14565]),
#    array([15107]),
#    array([15842]),
#    array([16920]),
#    array([14740]),
#    array([16401]),
#    array([9772]),
#    array([15055]),
#    array([16161]),
#    array([15585]),
#    array([15930]),
#    array([14418]),
#    array([17995]),
#    array([16293]),
#    array([16319]),
#    array([14822]),
#    array([15123]),
#    array([15925]),
#    array([14875]),
#    array([16622]),
#    array([16202]),
#    array([16715]),
#    array([15905]),
#    array([14908]),
#    array([15277]),
#    array([16177]),
#    array([15380]),
#    array([13940]),
#    array([15681]),
#    array([16344]),
#    array([15349]),
#    array([14873]),
#    array([15490]),
#    array([16518]),
#    array([17744]),
#    array([9931]),
#    array([16737]),
#    array([16098]),
#    array([14501]),
#    array([16706]),
#    array([14638]),
#    array([10170]),
#    array([15068]),
#    array([10468]),
#    array([17093]),
#    array([15274]),
#    array([15937]),
#    array([10219]),
#    array([14723]),
#    array([16628]),
#    array([15354]),
#    array([17498]),
#    array([10310]),
#    array([15577]),
#    array([14596]),
#    array([15476]),
#    array([10291]),
#    array([10294])]])

# %%
def euclidean_distance(a, b):
    return np.linalg.norm(np.array(a) - np.array(b))

# %%
def kmedoids(X, k, max_iters=100):
    np.random.seed(42)
    medoids = X[np.random.choice(range(len(X)), k, replace=False)]
    
    for _ in range(max_iters):
        clusters = [[] for _ in range(k)]
        
        # Assign points to nearest medoid
        for point in X:
            distances = np.linalg.norm(medoids - point, axis=1)  # vectorized
            cluster_idx = np.argmin(distances)
            clusters[cluster_idx].append(point)
        
        new_medoids = []
        for cluster in clusters:
            if cluster:
                cluster = np.array(cluster)
                # Compute distance matrix efficiently with NumPy
                dist_matrix = np.linalg.norm(cluster[:, None] - cluster[None, :], axis=2)
                total_distances = dist_matrix.sum(axis=1)
                new_medoids.append(cluster[np.argmin(total_distances)])
            else:
                # keep the old medoid if cluster empty
                new_medoids.append(medoids[len(new_medoids)])
        
        new_medoids = np.array(new_medoids)
        
        if np.allclose(medoids, new_medoids):
            break
        medoids = new_medoids
    
    return medoids, clusters

# %%
# Run k-medoids
medoids, clusters = kmedoids(X, k=3)

# Print results
print("Medoids:")
print(medoids)

print("\nClusters:")
for i, cluster in enumerate(clusters):
    print(f"Cluster {i+1}: {cluster}")
# Out:
# Medoids:
# [[ 1914]
#  [ 4460]
#  [14625]]
#
# Clusters:
# Cluster 1: [array([1144]), array([1291]), array([1887]), array([1171]), array([816]), array([1088]), array([1330]), array([1538]), array([1350]), array([1441]), array([1201]), array([1314]), array([1539]), array([1311]), array([1570]), array([1348]), array([1671]), array([1028]), array([1336]), array([1207]), array([1178]), array([692]), array([931]), array([1126]), array([1110]), array([1051]), array([1197]), array([1904]), array([1052]), array([1045]), array([1038]), array([1596]), array([1589]), array([1411]), array([1291]), array([1407]), array([1877]), array([966]), array([1464]), array([704]), array([1109]), array([1347]), array([1756]), array([1756]), array([1042]), array([1444]), array([1741]), array([1719]), array([1217]), array([1140]), array([1878]), array([705]), array([1946]), array([1414]), array([602]), array([1052]), array([1295]), array([1424]), array([1359]), array([1168]), array([1097]), array([691]), array([1316]), array([1276]), array([1289]), array([1293]), array([1353]), array([1132]), array([1670]), array([837]), array([1550]), array([1540]), array([1256]), array([1394]), array([1341]), array([1289]), array([1112]), array([2339]), array([1468]), array([1334]), array([1457]), array([1603]), array([615]), array([1068]), array([1590]), array([1531]), array([1212]), array([1237]), array([1413]), array([1516]), array([1276]), array([1564]), array([1465]), array([1286]), array([1312]), array([1673]), array([1313]), array([1609]), array([1158]), array([836]), array([1289]), array([1487]), array([1259]), array([1298]), array([1226]), array([1566]), array([1022]), array([1235]), array([1951]), array([1047]), array([1342]), array([1107]), array([1251]), array([1305]), array([1388]), array([1235]), array([2089]), array([1626]), array([1111]), array([1553]), array([1064]), array([1243]), array([1659]), array([1594]), array([1268]), array([1304]), array([1368]), array([720]), array([1521]), array([1137]), array([978]), array([1221]), array([1565]), array([1578]), array([1493]), array([1178]), array([991]), array([2560]), array([1657]), array([1204]), array([673]), array([1131]), array([1576]), array([1217]), array([530]), array([739]), array([1617]), array([1592]), array([1343]), array([1303]), array([1351]), array([1910]), array([1298]), array([1087]), array([1439]), array([1238]), array([1716]), array([1099]), array([1058]), array([1285]), array([1651]), array([1152]), array([1767]), array([1039]), array([1130]), array([1645]), array([1413]), array([1218]), array([597]), array([2184]), array([1592]), array([1388]), array([757]), array([1504]), array([1503]), array([1105]), array([2398]), array([1661]), array([1421]), array([999]), array([1387]), array([1243]), array([1860]), array([1502]), array([1460]), array([1348]), array([1087]), array([1226]), array([1230]), array([1555]), array([1827]), array([1376]), array([1771]), array([1873]), array([1679]), array([1002]), array([1344]), array([1461]), array([760]), array([1428]), array([1777]), array([1302]), array([1483]), array([1060]), array([1330]), array([1229]), array([886]), array([844]), array([1450]), array([2311]), array([1378]), array([1033]), array([1523]), array([1374]), array([1080]), array([1234]), array([1600]), array([1155]), array([1353]), array([1546]), array([1590]), array([1448]), array([1271]), array([1223]), array([1117]), array([994]), array([1468]), array([1658]), array([1368]), array([1218]), array([702]), array([1516]), array([1310]), array([1767]), array([933]), array([1512]), array([829]), array([1120]), array([1506]), array([1384]), array([817]), array([2094]), array([815]), array([510]), array([1377]), array([1193]), array([1287]), array([701]), array([1770]), array([1409]), array([1354]), array([1765]), array([1192]), array([687]), array([1227]), array([1737]), array([1348]), array([1435]), array([1321]), array([1479]), array([1283]), array([689]), array([965]), array([1541]), array([1258]), array([1339]), array([1007]), array([1387]), ar ...
# Cluster 2: [array([4311]), array([3231]), array([3280]), array([3753]), array([3663]), array([3490]), array([3981]), array([4027]), array([3597]), array([4088]), array([4449]), array([3946]), array([3795]), array([3320]), array([3193]), array([3228]), array([3567]), array([3396]), array([4605]), array([3306]), array([3530]), array([3382]), array([3483]), array([3342]), array([3253]), array([3951]), array([3479]), array([4563]), array([3676]), array([3313]), array([3291]), array([3305]), array([4686]), array([3902]), array([3328]), array([4291]), array([3703]), array([3407]), array([3891]), array([3942]), array([3994]), array([3774]), array([3386]), array([3503]), array([3319]), array([4157]), array([3753]), array([4776]), array([3784]), array([3360]), array([4014]), array([3327]), array([3395]), array([3725]), array([3630]), array([3347]), array([3519]), array([3762]), array([4107]), array([3508]), array([4148]), array([3189]), array([3670]), array([3891]), array([3264]), array([3432]), array([4254]), array([3444]), array([3700]), array([4063]), array([4542]), array([3203]), array([3343]), array([4357]), array([3910]), array([3888]), array([3783]), array([3428]), array([4189]), array([3302]), array([3347]), array([3762]), array([3899]), array([4303]), array([3871]), array([4642]), array([3626]), array([3764]), array([4535]), array([3277]), array([3265]), array([3598]), array([4263]), array([3709]), array([3806]), array([4345]), array([3292]), array([3432]), array([3447]), array([4428]), array([4149]), array([3446]), array([4370]), array([3546]), array([3974]), array([3346]), array([3369]), array([3253]), array([3259]), array([4085]), array([4074]), array([3982]), array([3448]), array([4099]), array([3814]), array([3411]), array([3525]), array([3580]), array([4491]), array([3205]), array([3699]), array([4740]), array([3215]), array([3210]), array([3281]), array([3829]), array([4042]), array([5029]), array([3345]), array([3284]), array([4252]), array([3738]), array([3393]), array([3600]), array([4822]), array([3568]), array([4121]), array([3569]), array([3542]), array([4439]), array([3656]), array([3692]), array([3575]), array([5176]), array([3956]), array([3561]), array([3323]), array([3457]), array([4150]), array([3310]), array([3897]), array([4316]), array([3903]), array([3242]), array([3411]), array([4040]), array([4381]), array([4166]), array([3533]), array([3415]), array([3927]), array([3534]), array([3524]), array([3964]), array([3393]), array([4129]), array([3742]), array([4160]), array([3817]), array([3355]), array([3921]), array([3866]), array([3435]), array([3937]), array([3533]), array([3295]), array([4165]), array([3948]), array([3222]), array([3999]), array([3913]), array([3814]), array([4399]), array([3246]), array([4075]), array([3448]), array([3731]), array([3732]), array([3968]), array([3915]), array([3695]), array([3271]), array([4098]), array([3607]), array([3625]), array([4976]), array([3929]), array([3786]), array([3591]), array([4599]), array([4549]), array([3636]), array([4066]), array([4929]), array([4101]), array([3990]), array([3355]), array([3553]), array([4740]), array([3732]), array([3569]), array([3502]), array([4277]), array([3951]), array([3452]), array([3756]), array([4294]), array([4199]), array([3942]), array([3637]), array([3563]), array([3367]), array([3395]), array([3798]), array([3504]), array([3411]), array([3943]), array([3928]), array([3849]), array([3925]), array([3422]), array([4044]), array([4222]), array([4238]), array([3658]), array([3212]), array([3495]), array([4314]), array([4478]), array([4089]), array([3591]), array([4221]), array([3982]), array([3825]), array([4077]), array([4014]), array([4251]), array([3683]), array([3250]), array([4010]), array([3676]), array([3927]), array([3337]), array([3275]), array([3294]), array([4470]), array([3640]), array([3948]), array([3739]), array([3205]), array([3446]), array([4143]), array([4248]), array([4084]), array([3650]), array([3292]) ...
# Cluster 3: [array([12535]), array([13794]), array([14771]), array([14373]), array([13173]), array([13363]), array([12956]), array([15139]), array([14132]), array([13015]), array([15511]), array([14833]), array([13630]), array([14213]), array([14276]), array([14264]), array([15423]), array([13400]), array([14965]), array([12871]), array([13945]), array([15200]), array([11603]), array([13820]), array([12603]), array([12478]), array([14334]), array([12403]), array([14576]), array([13324]), array([14465]), array([14567]), array([12896]), array([13360]), array([13787]), array([13677]), array([13119]), array([15106]), array([14084]), array([15078]), array([13670]), array([13719]), array([14603]), array([15019]), array([14954]), array([14490]), array([14242]), array([12429]), array([13970]), array([14426]), array([12592]), array([13109]), array([12631]), array([13090]), array([15203]), array([13179]), array([14901]), array([12593]), array([13452]), array([14533]), array([12510]), array([15578]), array([14880]), array([13653]), array([14107]), array([14223]), array([13791]), array([14137]), array([14319]), array([12257]), array([13124]), array([13212]), array([14244]), array([13303]), array([17064]), array([13598]), array([15209]), array([16171]), array([14991]), array([15077]), array([16202]), array([14703]), array([13280]), array([15039]), array([13997]), array([13866]), array([13847]), array([14955]), array([14615]), array([13764]), array([13945]), array([15091]), array([13627]), array([14252]), array([13376]), array([15391]), array([13740]), array([12867]), array([14844]), array([15079]), array([15549]), array([13092]), array([12941]), array([13681]), array([14455]), array([13672]), array([13854]), array([14308]), array([13753]), array([14071]), array([15180]), array([13090]), array([12777]), array([15738]), array([14557]), array([13678]), array([14743]), array([14082]), array([14119]), array([14149]), array([13758]), array([13617]), array([14326]), array([16161]), array([14716]), array([15999]), array([13830]), array([12025]), array([13988]), array([14511]), array([14074]), array([12906]), array([13142]), array([14465]), array([13816]), array([14696]), array([13138]), array([15121]), array([14544]), array([14747]), array([12980]), array([14643]), array([15473]), array([14428]), array([15033]), array([14624]), array([12493]), array([13085]), array([15527]), array([13814]), array([15102]), array([14414]), array([13177]), array([14748]), array([14084]), array([13781]), array([14779]), array([14042]), array([14330]), array([14474]), array([17628]), array([12739]), array([14500]), array([15236]), array([15634]), array([13534]), array([13062]), array([15571]), array([13633]), array([14185]), array([13345]), array([16485]), array([15331]), array([14934]), array([14441]), array([13796]), array([14511]), array([14802]), array([13931]), array([13016]), array([15552]), array([12576]), array([14381]), array([13991]), array([16428]), array([13139]), array([15869]), array([15472]), array([15301]), array([12779]), array([14212]), array([15584]), array([15982]), array([15172]), array([14593]), array([14474]), array([14336]), array([13140]), array([14230]), array([13247]), array([14305]), array([14952]), array([14418]), array([14270]), array([15867]), array([15315]), array([14229]), array([13021]), array([14279]), array([13767]), array([14324]), array([12595]), array([13819]), array([14354]), array([14830]), array([16422]), array([13557]), array([16216]), array([15039]), array([14887]), array([13720]), array([13692]), array([14593]), array([14763]), array([13648]), array([14727]), array([13503]), array([13311]), array([14755]), array([14802]), array([13769]), array([14393]), array([14625]), array([14402]), array([15282]), array([15293]), array([13751]), array([14181]), array([13209]), array([14437]), array([13513]), array([13083]), array([12192]), array([15028]), array([14948]), array([14109]), array([14459]), array([14103]), array([15958]), arra ...
